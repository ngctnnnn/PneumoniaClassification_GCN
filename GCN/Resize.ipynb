# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import os
import glob
import numpy as np
import pandas as pd 
import tqdm.notebook as tqdm
import matplotlib.pyplot as plt

from multiprocessing.pool import Pool

# %%
img_size=224
def Resize(image):
    image = cv2.imread(image, cv2.IMREAD_GRAYSCALE) 
    image = cv2.resize(image,(img_size, img_size))
    return image

def Resize_images(sourcedir, destdir):
    print("---reading directory " + sourcedir + "---")
    filecnt = 1
    for filename in tqdm.tqdm(glob.glob(sourcedir + '/*')):
        imagemat = Resize(filename)
        cv2.imwrite(destdir+'/img-'+str(filecnt)+'.jpg', imagemat)  
        filecnt+=1
    print("--saved in " + destdir + "--")

# %%
root = '/content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/'

# %%
for folder in ['train', 'test', 'val']: 
    for cate in ['bacteria', 'virus', 'normal']:    
        sourcedir = (os.path.join(root, 'CXR_Reformat', folder, cate))
        destdir =  (os.path.join(root, 'CXR_Reformat_Resize', folder, cate))

        os.makedirs(destdir, exist_ok=True)
        print("The new directory is created!") 

        Resize_images(sourcedir, destdir)
# Out:
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/train/bacteria---
#   0%|          | 0/2045 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/train/bacteria--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/train/virus---
#   0%|          | 0/1090 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/train/virus--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/train/normal---
#   0%|          | 0/1058 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/train/normal--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/test/bacteria---
#   0%|          | 0/242 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/test/bacteria--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/test/virus---
#   0%|          | 0/148 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/test/virus--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/test/normal---
#   0%|          | 0/234 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/test/normal--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/val/bacteria---
#   0%|          | 0/503 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/val/bacteria--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/val/virus---
#   0%|          | 0/255 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/val/virus--
# The new directory is created!
# ---reading directory /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat/val/normal---
#   0%|          | 0/291 [00:00<?, ?it/s]
# --saved in /content/drive/MyDrive/COURSES/CS331/FinalProject/dataset/GraphCXR/CXR_Reformat_Resize/val/normal--
